# %%
import mysql.connector
import pandas as pd
import networkx as nx
import haversine
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import mysql.connector
#       2 import pandas as pd
#       3 import networkx as nx
#
# ModuleNotFoundError: No module named 'mysql'

# %%
# Replace these values with your MySQL server information
host = "localhost"
user = "root"
password = "2710"
database = "pt_network_berlin"

# %%
query = """
    SELECT s.stop_id, s.combined_location, ls.stop_order, ls.line_id, l.line_name, s.stop_name, l.type
    FROM line_stops_1960 ls
    INNER JOIN stops_df_1960 s ON ls.stop_id = s.stop_id
    INNER JOIN line_df_1960 l ON ls.line_id = l.line_id
    ORDER BY ls.line_id, ls.stop_order
    """

# %%
def get_network_data(query):
    mycursor.execute(query)

    results = mycursor.fetchall()
    columns = ["stop_id", "coordinate_location", "stop_order", "line_id", "line_name", "stop_name", "type"]
    df = pd.DataFrame(results, columns=columns)

    return df

# %%
try:
    # Establish a connection to the MySQL server
    connection = mysql.connector.connect(
        host=host,
        user=user,
        password=password,
        database=database
    )

    if connection.is_connected():
        print("Connected to MySQL")

    # For example, let's execute a simple query to fetch data from a table:
    mycursor = connection.cursor()
    
    df = get_network_data(query)
    

    # Don't forget to close the cursor and the connection when you're done.
    mycursor.close()
    connection.close()

except mysql.connector.Error as e:
    print(f"Error connecting to MySQL: {e}")
# Out:
# Connected to MySQL

# %%
def create_network_graph(df):
    # Create a network graph
    G = nx.MultiGraph()

    # Add nodes for each stop_id with coordinates as attributes
    for index, row in df.iterrows():
        stop_id = row["stop_id"]
        coordinates = row["coordinate_location"].split(",")
        if len(coordinates) == 2:
            coordinate_y = float(coordinates[0])
            coordinate_x = float(coordinates[1])
        else:
            # Handle the case where the coordinate_location is not 2 values separated by a comma
            coordinate_y = 0
            coordinate_x = 0

        G.add_node(stop_id, x=coordinate_x, y=coordinate_y)

# Add edges
    for line in set(df["line_id"]):
        df_line = df[df["line_id"] == line].sort_values("stop_order")
        line_name = df_line.iloc[0]["line_name"]  # get line name associated with line_id
        for i in range(len(df_line) - 1):
            source = df_line.iloc[i]["stop_id"]
            target = df_line.iloc[i + 1]["stop_id"]
            edge_type = df_line.iloc[i]["type"]
            weight = 1
            line_id = df_line.iloc[i]["line_id"]
            
            # Create a dictionary with edge attributes, including "type"
            edge_attributes = {
                "weight": weight,
                "key": line_id,
                "label": line_name,
                "type": edge_type
            }
            
            G.add_edge(source, target, **edge_attributes)

    return G

# %%
G = create_network_graph(df)

# %%
def add_graph_attributes(G, df):
    node_weights = {node: G.degree(node) for node in G.nodes()}
    nx.set_node_attributes(G, node_weights, "node_weight")

    #set node labels to stop names
    stop_names = {row["stop_id"]: row["stop_name"] for index, row in df.iterrows()}
    nx.set_node_attributes(G, stop_names, "node_label")

    return G

# %%
def add_distance_attribute(graph):
    for u, v, data in graph.edges(data=True):
        u_coord = (graph.nodes[u]["y"], graph.nodes[u]["x"])
        v_coord = (graph.nodes[v]["y"], graph.nodes[v]["x"])
        distance = haversine.haversine(u_coord, v_coord, unit="km")
        data["distance"] = distance
        data["edge_type"] = data["type"]


    return graph

# %%
G = add_graph_attributes(G, df)
G = add_distance_attribute(G)

# %%
for source, target, attrs in G.edges(data=True):
    if source == target:
        print(f"Self-loop edge: {source} to {target} has following attributes:")
        for attr_name, attr_value in attrs.items():
            print(f"{attr_name}: {attr_value}")
    else:
        None

# %% [markdown]
# Analysis

# %%
node_degrees = dict(G.degree())

# %%
# Create a copy of the original graph
G_coords = G.copy()

# Find and remove nodes with (0,0) coordinates from the copy
nodes_to_remove = [node for node, data in G_coords.nodes(data=True) if data['x'] == 0 and data['y'] == 0]
G_coords.remove_nodes_from(nodes_to_remove)

# %%
G_coords.nodes(data=True)
# Out:
# NodeDataView({992: {'x': 13.429517625327765, 'y': 52.50956365130009, 'node_weight': 1, 'node_label': 'SchillingBrÃ¼cke (Ostbahnhof)'}, 1193: {'x': 13.432938339097822, 'y': 52.51808306742478, 'node_weight': 2, 'node_label': 'U-Bhf. Strausberger Platz'}, 1077: {'x': 13.432938339097822, 'y': 52.51808306742478, 'node_weight': 2, 'node_label': 'Stalinallee'}, 659: {'x': 13.4326457, 'y': 52.5232658, 'node_weight': 8, 'node_label': 'Leninplatz'}, 10: {'x': 13.4110773, 'y': 52.5233439, 'node_weight': 2, 'node_label': 'Alexanderplats, Memhardstr.'}, 931: {'x': 13.4016121, 'y': 52.5301769, 'node_weight': 8, 'node_label': 'Rosenthaler Platz'}, 212: {'x': 13.3974236, 'y': 52.5324542, 'node_weight': 4, 'node_label': 'Brunnen Ecke Invalidenstrasse'}, 521: {'x': 13.3827302, 'y': 52.5304158, 'node_weight': 8, 'node_label': 'Invaliden- Ecke Chausseestrasse'}, 1253: {'x': 13.388097732360343, 'y': 52.52168602376861, 'node_weight': 6, 'node_label': 'WeidendammBrÃ¼cke, Bhf. Friedrichstrasse'}, 36: {'x': 13.3953839, 'y': 52.5194208, 'node_weight': 1, 'node_label': 'Am Kupfergraben'}, 641: {'x': 13.425367474591651, 'y': 52.50851870094253, 'node_weight': 1, 'node_label': 'KÃ¶penicker Strasse Ecke Adalbertstrasse'}, 127: {'x': 13.418056238742702, 'y': 52.51478599600389, 'node_weight': 2, 'node_label': 'Bhf. JannowitzBrÃ¼cke'}, 15: {'x': 13.4110773, 'y': 52.5233439, 'node_weight': 8, 'node_label': 'Alexanderplatz, Memhardstrasse'}, 797: {'x': 13.384570821924626, 'y': 52.52693581242043, 'node_weight': 2, 'node_label': 'Oranienburger Tor, Hannoversche Strasse'}, 580: {'x': 13.5104609, 'y': 52.4842462, 'node_weight': 1, 'node_label': 'Klingenberg, Blockdammweg'}, 559: {'x': 13.475466875195085, 'y': 52.502334098187674, 'node_weight': 2, 'node_label': 'Karlshorster Strasse'}, 503: {'x': 13.465969, 'y': 52.5088235, 'node_weight': 2, 'node_label': 'Holteistrasse'}, 329: {'x': 13.4540172, 'y': 52.5153903, 'node_weight': 4, 'node_label': 'Frankfurter Tor/Stalinallee'}, 101: {'x': 13.4525257, 'y': 52.519215, 'node_weight': 4, 'node_label': 'Bersarinplatz'}, 657: {'x': 13.4462368, 'y': 52.5259343, 'node_weight': 4, 'node_label': 'Leninallee'}, 587: {'x': 13.4406868, 'y': 52.5325286, 'node_weight': 5, 'node_label': 'Kniprodestrasse'}, 401: {'x': 13.4334045, 'y': 52.5364975, 'node_weight': 4, 'node_label': 'Greifswalder Strasse'}, 858: {'x': 13.4244789, 'y': 52.5396522, 'node_weight': 4, 'node_label': 'Prenzlauer Allee'}, 1157: {'x': 13.4113979, 'y': 52.5401928, 'node_weight': 14, 'node_label': 'U-Bhf. Dimitroffstrasse'}, 786: {'x': 13.404619006480333, 'y': 52.54058395613876, 'node_weight': 2, 'node_label': 'Oderberger Strasse'}, 255: {'x': 13.380145054879522, 'y': 52.423949959899865, 'node_weight': 1, 'node_label': 'Daimlerstrasse'}, 141: {'x': 13.375057660174704, 'y': 52.42613307832105, 'node_weight': 2, 'node_label': 'Bhf. Marienfelde'}, 539: {'x': 13.378266822562516, 'y': 52.43481849058747, 'node_weight': 2, 'node_label': 'K rtingstrasse'}, 718: {'x': 13.387234623097394, 'y': 52.44016299080784, 'node_weight': 2, 'node_label': 'Mariendorfer Damm'}, 515: {'x': 13.398564688322455, 'y': 52.443541863050356, 'node_weight': 2, 'node_label': 'Imbrosweg'}, 720: {'x': 13.404755931664896, 'y': 52.44953069256824, 'node_weight': 2, 'node_label': 'Mariendorfer Friedhof'}, 516: {'x': 13.409794385645863, 'y': 52.455350229930445, 'node_weight': 3, 'node_label': 'Industriestrasse'}, 369: {'x': 13.418009045149528, 'y': 52.46053782557012, 'node_weight': 4, 'node_label': 'Germaniastrasse'}, 332: {'x': 13.427509548910932, 'y': 52.463949908172545, 'node_weight': 2, 'node_label': 'Frauenklinik'}, 474: {'x': 13.432818109719008, 'y': 52.46476232618638, 'node_weight': 4, 'node_label': 'Hermannstrasse'}, 1179: {'x': 13.441614939772098, 'y': 52.46965567921364, 'node_weight': 4, 'node_label': 'U-Bhf. NeukÃ¶lln'}, 918: {'x': 13.446301038467002, 'y': 52.47097391592754, 'node_weight': 2, 'node_label': 'Richardstrasse'}, 153: {'x': 13.455499525035636, 'y': 52.47414312526527, 'node_weight': 4, ' ...

# %%
nx.write_gexf(G_coords, "network_graph_1960_with_coordinates.gexf")

# %% [markdown]
# Community detection
#
# community.best_partition(G): This function applies the Louvain community detection algorithm to the graph G. It iteratively optimizes the division of nodes into communities based on the network's structure. The goal is to maximize modularity, a measure of the quality of the community structure. Modularity measures how well nodes within a community are connected compared to what we would expect by random chance.

# %%
# Perform Louvain community detection
partition = community.best_partition(G)

# Display the communities with node labels
communities = {}
for node, community_id in partition.items():
    # Assuming 'node_label' is the attribute name
    node_label = G.nodes[node]['node_label']
    
    if community_id in communities:
        communities[community_id].append(node_label)
    else:
        communities[community_id] = [node_label]

for comm_id, node_labels in communities.items():
    print(f"Community {comm_id}: {node_labels}")
# Out:
# Community 1: ['SchillingBrÃ¼cke (Ostbahnhof)', 'U-Bhf. Strausberger Platz', 'Stalinallee', 'Platz der Vereinten Nationen', 'MemhardstraÃŸe', 'U Rosenthaler Platz', 'BrunnenstraÃŸe/InvalidenstraÃŸe', 'U Naturkundemuseum', 'WeidendammBrÃ¼cke, Bhf. Friedrichstrasse', 'Am Kupfergraben', 'KÃ¶penicker Strasse Ecke Adalbertstrasse', 'Bhf. JannowitzBrÃ¼cke', 'MemhardstraÃŸe', 'Oranienburger Tor, Hannoversche Strasse', 'Blockdammweg', 'Karlshorster Strasse', 'Boxhagener StraÃŸe/HolteistraÃŸe', 'U Frankfurter Tor', 'Bersarinplatz', 'Landsberger Allee/Petersburger StraÃŸe', 'KniprodestraÃŸe/Danziger StraÃŸe', 'Greifswalder StraÃŸe/Danziger StraÃŸe', 'Prenzlauer Allee/Danziger StraÃŸe', 'U Eberswalder StraÃŸe', 'Oderberger Strasse', 'Rosenthal Nord', 'NordendstraÃŸe', 'Grabbeallee/Pastor-NiemÃ¶ller-Platz', 'Rathaus Pankow', 'Pankow Kirche', 'U VinetastraÃŸe', 'S+U SchÃ¶nhauser Allee', 'Rosenthal Nord', 'MÃ¼hlenstrasse', 'S Warschauer StraÃŸe', 'Boxhagener Strasse', 'S+U Frankfurter Allee', 'Roederplatz', 'HohenschÃ¶nhauser StraÃŸe', 'Klement-Gottwald-Allee/Lichtenberger Strasse', 'Antonplatz', 'Prenzlauer Promenade', 'S+U SchÃ¶nhauser Allee', 'BjÃ¶rnsonstraÃŸe', 'GrÃ¼nberger StraÃŸe/Warschauer StraÃŸe', 'SchillerstraÃŸe', 'Nordend', 'Ossietzkyplatz', 'U VinetastraÃŸe', 'BrunnenstraÃŸe/InvalidenstraÃŸe', 'Oranienburger Tor', 'Am Kupfergraben', 'NiederschÃ¶nhausen, Idastrasse bzw. Nordend', 'Buchholz, Hauptstrasse', 'Blankenburger Weiche', 'S-Bhf. Pankow-Heinersdorf', 'Hackescher Markt, Gro e Pr sidentenstrasse', 'Hohensch nhausen, Gartenstadt', 'Falkenbergerstrasse Ecke Wartenberger Strasse', 'Degnerstrasse', 'Wei enseer Weg', 'Steuerhaus', 'Dimitroffstrasse', 'Hohensch nhausen, Falkenberger Strasse', 'Alexanderplatz, Grunestrasse', 'Jacobystrasse', 'U-Bhf. Neanderstrasse', 'Spittelmarkt', 'D nhoffplatz', 'Hackescher Markt', 'Invalidenstrasse Ecke Chausseestrasse', 'Walter-Ulbricht-Stadion', 'Stadion Buschallee', 'Buschallee Ecke Klement-Gottwald-Allee', 'Humannplatz', 'Am Kupfergraben (Haus der Frau)', 'Heinersdorf, Romain-Rolland-Str.', 'Heinersdorf, Kirche', 'Am Steinberg', 'Prenzlauer Allee Ecke Wisbyer Strasse', 'S-Bhf. Prenzlauer Allee', 'SaarBrÃ¼cker Strasse', 'Prenzlauer Tor', 'Alexanderplatz, Grunerstrasse', 'J denstrasse, Mokenmarkt', 'Wei ensee, Pasedagplatz', 'Klement-Gottwald-Allee Ecke Bernkasteler Strasse', 'J denstrasse, Molkenmarkt', 'Taubenstrasse', 'Wie ensee, Pasedagplatz', 'BVG-Bf. Wei ensee', 'S-Bhf. Greifswalder Strasse', 'KÃ¶nigstor', 'Leipziger Platz', 'Klement-Gottwald-Allee']
# Community 2: ['Daimlerstrasse', 'Bhf. Marienfelde', 'KÃ¶rtingstrasse', 'Mariendorfer Damm', 'Imbrosweg', 'Mariendorfer Friedhof', 'Industriestrasse', 'Germaniastrasse', 'Frauenklinik', 'Hermannstrasse', 'U-Bhf. NeukÃ¶lln', 'Richardstrasse', 'Bhf. Sonnenallee', 'Dammweg', 'Schulenburgpark', 'SÃ¼dstern', 'Hermannplatz', 'Spreewaldplatz', 'Reichenberger Strasse', 'Glogauer Strasse', 'Sonnenallee', 'Weichselstrasse', 'Rathaus NeukÃ¶lln', 'Saltykowstrasse', 'Karl-Marx-Platz', 'Silbersteinstrasse', 'StÃ¤dtische Frauenklinik', 'Bhf. Teltowkanal', 'U-Bhf. Grenzallee', 'Buschkrug', 'Britzer Damm', 'Bhf. NeukÃ¶lln', 'Elsenstrasse', 'KÃ¶penicker Landstrasse Ecke Baumschulenstrasse', 'Am Treptower Park Ecke Bulgarische Strasse', 'Wiener BrÃ¼cke', 'Skalitzer Strasse', 'Erkstrasse', 'Hertzbergplatz', 'Schwarzer Weg']
# Community 3: ['Wolliner StraÃŸe', 'Voltastrasse', 'Weddingplatz', 'Alt-Moabit/â€‹Rathenower Str.', 'Stromstrasse', 'GotzkowskybrÃ¼cke', 'U-Bhf. Ernst-Reuter-Platz', 'Bhf. Zoo', 'Wittenbergplatz', 'RÃ¼gener Strasse', 'Bhf. Gesundbrunnen', 'Nauener Platz', 'Augustenburger Platz', 'U TurmstraÃŸe', 'Gotzkowskystrasse', 'Wartburgplatz', 'Rathaus SchÃ¶neberg', 'Hauptstrasse/Dominicusstrasse', 'Gotenstrasse', 'OsnabrÃ¼cker Strasse', 'Wiebestrasse', 'Bhf. Beusselstrasse', 'U Osloer StraÃŸe', 'GrÃ¼ntaler StraÃŸe', 'Nonnendammallee', 'Quellweg', 'Bhf. Jungfernheide', 'Tauroggener Strasse', 'Wiebestrasse/Huttenstrasse', 'Nettelbeckplatz', 'Louise-Schroeder-Platz', 'Pankower Allee', 'Kopenhagener Strasse', 'Bhf. Wilhelmsruh', 'S+U Hauptbahnhof', 'Nollendorfplatz', 'U-Bhf. Ernst-Reuter-Platz', 'Richard-Wagner-Platz', 'Luisenplatz', 'Cauerstrasse', 'Siemensplatz', 'Paulsternstrasse', 'Zitadellenweg', 'Wintersteinstrasse', 'Bhf. Papestrasse', 'Tempelhofer Damm', 'Gottlieb-Dunkel-Strasse', 'Hauptstrasse (SchÃ¶neberg)', 'Bosestrasse', 'Eythstrasse', 'Belziger Strasse']
# Community 5: ['Potsdamer Strasse', 'Bhf. Yorckstrasse', 'Mehringdamm', 'Martin-Luther-Strasse', 'Bundesallee', 'Fehrbelliner Platz', 'KurfÃ¼rstendamm', 'Otto-Suhr-Allee', 'Kantstrasse', 'Hildegardstrasse', 'Bundesplatz', 'Schlossstrasse', 'Rathaus Steglitz', 'Bhf. Steglitz', 'SchÃ¼tzenstrasse', 'Birkbuschstrasse', 'Kaiser-Friedrich-Strasse', 'Stuttgarter Platz', 'Bhf. Lichterfelde-Ost', 'Wiesenbaude', 'Moltkestrasse', 'H ndelplatz', 'Finckensteinallee', 'Grunewaldstrasse', 'Friedrich-Wilhelm-Platz', 'Hindenburgdamm', 'Bhf. Botanischer Garten', 'Bhf. Lichterfelde-West', 'Rittberg-Krankenhaus', 'Wismarer Strasse', 'Goerzallee', 'Lindenstrasse', 'RÃ¶blingstrasse', 'Bhf. Mariendorf', 'Friedrichstrasse', 'Lankwitz, Kirche', 'Seydlitzstrasse', 'Berliner Strasse', 'Glesendorfer Strasse', 'Osdorfer Strasse', 'Schwelmer Strasse', 'Mehringplatz', 'Yorckstrasse']
# Community 6: ['Hobrechtstrasse', 'Hasenheide', 'U-Bhf. Boddinstrasse', 'U-Bhf. Leinestrasse', 'Bhf. Hermannstrasse', 'Mariendorfer Weg', 'Germaniapromenade', 'Franz-KÃ¶rner-Strasse', 'Gradestrasse', 'Tempelhofer Weg', 'Mariendorfer Allee', 'Gutschmidstrasse', 'Kleinbahn', 'Dacchdeckerweg', 'Parkfriedhof NeukÃ¶lln', 'Alt-Buckow', 'U-Bhf. SÃ¼dstern']
# Community 9: ['Wilmersdorfer Strasse', 'KÃ¶nigin-Elisabeth-Strasse', 'Kirschenallee', 'Schloss Ruhwald', 'U-Bhf. Ruhleben', 'Teltower Strasse', 'Spandau, Markt', 'Carl-Schurz-Strasse', 'Hafenplatz', 'Hohenzollernring', 'Hakenfelde', 'Johannesstift', 'Rathaus Spandau', 'Nauener Strasse', 'Spandauer Damm', 'Klausenerplatz', 'Bhf. Zoo, Kantstrasse', 'Amtsgericht', 'Messedamm', 'Reichskanzlerplatz', 'Bhf. Heerstrasse', 'Reichssportfeldstrasse', 'St enseeBrÃ¼cke', 'Pichelsdorfer Strasse', 'Weverstrasse, Strassenbahnhof', 'Seeburger Strasse', 'Spandau, Johannesstift', 'StÃ¶ssenseebrÃ¼cke', 'Kanststrasse Ecke Joachimsthaler Strasse']
# Community 13: ['Onkel-Herse-Strasse', 'Parchimer Allee', 'Krankenhaus NeukÃ¶lln', 'Johannisthaler Chaussee', 'Wildmeisterdamm', 'Stubenrauchstrasse', 'KÃ¶penicker Strasse', 'Bahnhofstrasse', 'Mahlsdorf-SÃ¼d, Hubertus', 'S-Bhf. KÃ¶penick', 'Bahnhofstrasse Ecke Lindenstrasse', 'Parkstrasse', 'Wilhelminenhof- Ecke Edisonstrasse', 'Treskowallee Ecke Ehrlichstrasse', 'Blockdammweg Ecke KÃ¶penicker Chaussee', 'Hauptstrasse Ecke Karlshorster Strasse', 'S-Bhf. Ostkreuz', 'Stralauer Allee Ecke Markgrafendamm', 'Warschauer Strasse', 'Ostbahnhof', 'Andreasstrasse', 'Blumenstrasse/Schicklerstrasse', 'WendenschloÃŸ Ecke Ekhofstrasse', 'Strassenbahnhof KÃ¶penick', 'SchÃ¼ÃŸlerplatz', 'Lindenstrasse Ecke Bahnhofstrasse', 'Uhlenhorst', 'Mahlsdorf-SÃ¼d', 'Hubertus', 'BÃ¼tower Strasse', 'S-Bhf. Mahlsdorf', 'Altglienicke, Am Falkenberg', 'Benzolwerk', 'S-Bhf. Adlershof', 'Marktplatz', 'S-Bhf. Spindlersfeld', 'KÃ¶llnischer Platz', 'Seelenbinderstrasse', 'Hirschgarten', 'FÃ¼rstenwalder Damm', 'S-Bhf. Friedrichshagen', 'Brauerei', 'Friedrichshagen, Wasserwerk', 'Alt-SchmÃ¶ckwitz', 'Vetschauer Allee', 'Richtershorn', 'RegattahÃ¤user', 'Bhf. GrÃ¼nau', 'Chemische Fabrik', 'Vollkropfgraben', 'Rahnsdorf', 'Wilhelminenhofstrasse Ecke Edisonstrasse']
# Community 10: ['Innsbrucker Platz', 'Traegerstrasse', 'Cecilieng rten', 'Rembrandtstrasse', 'Canovastrasse (Krankenhaus)', 'Thorwaldsenstrasse', 'Bergstrasse', 'Kaisereiche', 'Lauterplatz', 'Dominicusstrasse', 'Albertstrasse', 'Kaiser-Wilhelm-Platz', 'U-Bhf. BÃ¼lowstrasse', 'LÃ¼tzowstrasse', 'Potsdamer Platz', 'Stadtpark', 'Lauenburger Platz', 'Eisenacher Strasse', 'Anhalter Bahnhof', 'U-Bhf. Kochstrasse', 'Oranienstrasse', 'U-Bhf. Moritzplatz']
# Community 11: ['Johannisthal, Haeckelstrasse', 'KÃ¶nigsweide', 'Bhf. SchÃ¶neweide', 'Wilhelminenhofstrasse', 'S-Bhf. Karlshorst', 'Hochschule f r konomie', 'Tierpark Berlin', 'Schlossstrasse Ecke Alt-Friedrichsfelde', 'Bhf. Lichtenberg', 'BVG-Bf. Lichtenberg, Siegfriedstrasse', 'Klubhaus VEB Elektrokohle', 'Treptow, Flutgraben', 'S-Bhf. Treptow', 'Bulgarische Strasse', 'Baumschulenstrasse', 'Britzer Strasse', 'Bhf. Oberspree']
# Community 14: ['Attilaplatz', 'Berlinickeplatz', 'Hoeppnerstrasse', 'Adolf-Scheidt-Platz', 'U-Bhf. Flughafen', 'Gneisenaustrasse', 'BlÃ¶cherplatz', 'Baerwaldstrasse', 'Urban-Krankenhaus', 'U-Bhf. Tempelhof', 'Alt-Tempelhof', 'Kaiserin-Augusta-Strasse', 'Friedrich-Karl-Strasse', 'Mehringplatz (Hallesches Tor)', 'Yorckstrasse/Gneisenaustrasse', 'U-Bhf. Paradestrasse', 'Bahnhof Tempelhof', 'Kaiserstrasse', 'PrÃ¼hÃŸstrasse', 'Mariendorfer Damm Ecke Alt-Mariendorf', 'Grossbeerenstrasse Ecke Daimlerstrasse', 'Daimlerstrasse Ecke Birnhornweg', 'Flughafen Tempelhof', 'Rathaus Tempelhof', 'Alt-Mariendorf', 'Rennbahn', 'Marienfelder Chaussee', 'Marienfelder Strasse', 'Bhf. Lichtenrade']
# Community 15: ['Baumschulenweg, Sonnenallee', 'KÃ¶penicker landstrasse', 'S-Bhf. SchÃ¶neweide', 'Wilhelminenhofstrasse, Edisonstrasse', 'Pionierrepublik', 'Lindenstrasse, Bahnhofstrasse', 'GrÃ¼nstrasse', 'KÃ¶penick, Krankenhaus']
# Community 16: ['Machnower Schleuse', 'Alte Wagenhalle', 'Neue Wagenhalle', 'Hamburger Platz', 'Ruhlsdorfer Platz', 'Fritz-Reuter Strasse', 'Teltow, Paul-Gerhardt-Strasse']
# Community 24: ['Waldstrasse', 'Otto-Surh-Allee', 'Holzhauser Strasse', 'Cyclopstrasse', 'Zabel-KrÃ¼ger-Damm', 'Kirchstrasse', 'Hermsdorfer Damm', 'Bhf. Frohnau', 'Donnersmarckplatz', 'Hainbuchenstrasse', 'Rathaus Reinickendorf', 'Schildower Strasse', 'Oswinsteig', 'Hohefeldstrasse', 'Im Fischgrund', 'Alt-Heiligensee', 'Am Dachsbau', 'Gabelung', 'Ruppiner Chaussee', 'U-Bhf. Tegel', 'Mattenbuder Pfad', 'Bhf. Heiligensee', 'Bhf. Schulzendorf', 'Heiligenseestrasse', 'Ziekowstrasse', 'Nordgraben', 'Borsigwalder Weg', 'GorkiStrasse', 'Am Flie', 'Schulzendorfer Strasse', 'Bhf. Hermsdorf', 'Dominikus-Krankenhaus', 'Tegelort', 'Walderseestrasse', 'Falkenplatz', 'MÃ¼hlenstrasse', 'Karolinenstrasse', 'Hatzfeldallee', 'Martin-Luther-Friedhof', 'Freie Scholle', 'Bhf. Waidmannslust', 'Oraniendamm', 'Am Vierrutenbert', 'LÃ¼bars, Dorfaue']
# Community 18: ['KurfÃ¼rstendamm', 'U-Bhf. Fehrbelliner Platz', 'Detmolder Strasse', 'Breitenbachplatz', 'Botanischer Garten', 'Pacelli-/Thielallee', 'Clayallee', 'Berliner Strasse', 'EinemStrasse', 'Rathaus Sch neberg', 'Innsbrucker Platz', 'Bundesplatz', 'Wiesbadener Strasse', 'Englerallee', 'Bundesallee', 'Rathaus Steglitz', 'Stadtpark', 'LeonorenStrasse', 'Stadion Lichterfelde', 'U-Bhf. Flughafen', 'Flughafen', 'Strasse des 17. Juni', 'U-Bhf. Ernst-Reuter-Platz', 'Bhf. Zoo', 'U-Bhf. Spichernstrasse', 'Bhf. Hohenzollerndamm', 'Anhalter Bhf.', 'U-Bhf. Hallesches Tor', 'Gneisenaustrasse', 'Columbiadamm', 'Tempelhofer Damm', 'Kaisereiche', 'Grazer Platz', 'Attilaplatz', 'LÃ¼tzowstrasse', 'GritznerStrasse', 'SchlossStrasse', 'SedanStrasse', 'StindeStrasse', 'Dominicusstrasse', 'Kaiser-Wilhelm-Platz', 'Friesenstrasse', 'U-Bhf. Boddinstrasse', 'Rathaus NeukÃ¶lln', 'Finowstrasse', 'Goeben-/Pallasstrasse', 'U-Bhf. BÃ¼lowstrasse', 'Margaretenstrasse', 'Roseneck, Hundekehl', 'Warnem nder/Berkaer Strasse', 'Zappoter/Oeynhauser Strasse', 'Hamburger Strasse, Rudolf-Mosse-Platz', 'U-Bhf. Heidelberger Platz', 'Brabanter Platz', 'Am Volkspark', 'Postamt', 'G ntzelstrasse', 'Ludwigkirchstrasse/Pariser Strasse', 'U-Bhf. Heidelberg Platz', 'Bhf. Sch neberg', 'Berlinickeplatz', 'Bhf. Tempelhof', 'U-Bhf. Paradesstrasse', 'Flughafen Tempelhof', 'Vogelsang', 'Thielallee/Pacelliallee', 'U-Bhf. Dahlem-Dorf', 'Postamt, Museum Dahlem', 'Arnimallee', 'Kaiser-Wilhelm-Strasse', 'Lepsiusstrasse', 'Cauerstrasse', 'HardenbergStrasse', 'Rankeplatz, Bundeshaus', 'Schlossstrasse, Wilhelm-Schreiber-Platz', 'Canovastrasse', 'Mariendorfer Damm', 'Alt-Mariendorf', 'Tauernallee, Adlerm hle', 'Buckower Chaussee', 'Lichtenrade, Goethestrasse', 'Goltzstrasse', 'Lichtenrade, Blohmstrasse Ecke W nsdorfer Strasse', 'Rankeplatz/Bundeshaus']
# Community 19: ['U-Bhf. Oskar-Helene-Heim', 'Potsdamer Strasse', 'Bhf. Zehlendorf', 'Beeskowdamm', 'Wismarer Strasse', 'Lindenstrasse', 'Elsterplatz', 'Hundekehlestrasse', 'KÃ¶nigin-Luise-Strasse', 'U-Bhf. Thielplatz', 'Dahlemer Weg', 'Teltower Damm', 'Behring-Krankenhaus', 'Lupsteiner Weg', 'Saargem nder Strasse', 'Ihnestrasse', 'Corrensplatz', 'Under den Eichen', 'Bhf. Lichterfelde-West', 'Ringstrasse', 'Wiesenbaude', 'Bhf. Grunewald', 'Hagenplatz', 'Rosenecke', 'Warnem nder Strasse', 'U-Bhf. RÃ¼desheimer Platz', 'Friedriche-Wilhelm-Platz', 'Sophie-Charlotten-Strasse', 'Scharfestrasse', 'Mittelstrasse', 'Wolzogenstrasse', 'Benschallee', 'Roseneck', 'Erdener Strasse', 'Rathaus Zehlendorf', 'Winifriedstrasse', 'Sundgauer Strasse', 'U-Bhf. Onkel-Toms-H tte', 'U-Bhf. Krumme Lanke', 'Bhf. Lindenthaler Allee', 'Potsdamer Strasse Ecke Fischerh ttenstrasse', 'Drakestrasse', 'Hindenburgdamm', 'Hohenzollerndamm', 'Forckenbeckstrasse', 'Flinsberger Platz', 'Cunostrasse', 'Krumme Lanke', 'Sven-Hedin-Strasse', 'Hartmannsweiler Weg', 'Seehofstrasse', 'Knesebeckstrasse', 'J nickestrasse', 'Osteweg', '4. Ring', 'Luzerner Strasse', 'Thuner Platz', 'Berkaer Strasse, Elsterplatz', 'P cklerstrasse', 'Winfriedstrasse', 'Clayallee/Teltower Damm']
# Community 20: ['Haselhorst, Kirche', 'Paulsternstrasse', 'Verwaltungs-GebÃ¤ude', 'Spandauer Damm', 'U-Bhf. Kaiserdamm', 'Amtsgerichsplatz', 'Krankenhaus Tegel-SÃ¼d', 'Strasse nach Staatwinkel', 'Daumstrasse', 'Havelstrasse', 'Scharnweberstrasse', 'Kurt-Schumacher-Platz', 'Kaserne SÃ¼dtor', 'Heckerdamm', 'Bhf. Jungfernheide', 'Luisenplatz', 'Kantstrasse', 'Stuttgarter Platz', 'Amtsgericht Charlottenburg', 'Kaserne, SÃ¼dtor', 'Saatwinkler Damm', 'Richard-Wagner-Platz', 'Goebelplatz', 'Kurt-Schumacher-Damme', 'Landgericht', 'SchlossBrÃ¼cke', 'Bhf. Westend', 'KÃ¶nigin-Elisabeth-Strasse', 'FÃ¼rstenbrunner Weg', 'Schloss Ruhwald']
# Community 21: ['Bhf. Halensee', 'Hansaplatz', 'Tiergartenstrasse', 'LÃ¼tzowplatz', 'Wilmersdorfer Strasse', 'Olivaer Platz', 'Joachimstaler Strasse', 'Breitscheidplatz', 'Wittenbergplatz', 'Nollendorfplatz', 'Wiebestrasse', 'GotzkowskyStrasse', 'StromStrasse', 'Rathenower Strasse', 'Alt-Moabit', 'John-Foster-Dulles-Allee', 'Unionplatz', 'GotzkowskybrÃ¼cke', 'Berkaer Strasse', 'BSC-Sportplatz', 'Bismarckplatz', 'Joachim-Friedrich-Strasse', 'Uhlandstrasse', 'Lutherstrasse', 'Brixplatz', 'Reichskanzlerplatz', 'Messedamm', 'Hochmeisterplatz', 'Konstanzer Strasse', 'Ruhrstrasse', 'Fehrbelliner Platz', 'Emser Platz', 'Nassauische Strasse', 'Prager Platz', 'Marburger Strasse', 'Masurenallee', 'Rathenauplatz', 'Wichmannstrasse', 'Gro er Stern', 'Bhf. Bellevue', 'Turmstrasse', 'Perleberger Strasse', 'Stephanplatz', 'Leibnizstrasse', 'Bleibtreustrasse', 'Kongre halle', 'Brandenburger Tor', 'Am Nordhafen', 'Turmstrasse/Rathenower Strasse', 'Krankenhaus Moabit', 'Stromstrasse', 'Rathaus Tiergarten', 'Waldstrasse/Gotzkowskystrasse', 'Reuchlinstrasse', 'Wiebestrasse, Strassenbahnhof']
# Community 29: ['Marienstrasse', 'Bismarckstrasse', 'Bhf. Lichterfelde-Ost', 'Lange Strasse', 'Hildburghauser Strasse', 'Trippsteinstrasse', 'Friedrich-Wilhelm-Platz', 'Schlossstrasse', 'Bhf. Feuerbachstrasse', 'Bergstrasse', 'Steglitzer Damm', 'Leonorenstrasse', 'Lankwitz, Kirche', 'Havensteinstrasse', 'Lerbacher Weg', 'Marienfelder Strasse', 'Marchandstrasse', 'Marienfelder Allee', 'Stegerwaldstrasse', 'Bhf. Marienfelde', 'Klingsorstrasse', 'Sedanstrasse', 'Halskestrasse', 'Bhf. SÃ¼dende', 'Bhf. Mariendorf', 'KurfÃ¼rstenstrasse', 'Kaiserstrasse/Ringstrasse', 'Rathaus Mariendorf', 'Kaiserstrasse', 'Munsterdamm', 'Grazer Damm, OverbeckStrasse']
# Community 25: ['Weddingplatz', 'Schulstrasse', 'U-Bhf. Seestrasse', 'Barfusstrasse', 'Bristolstrasse', 'Emmentaler Strasse', 'Lindauer Strasse', 'Lindenweg', 'Oranienburger Strasse', 'Bernauer Strasse', 'Aroser Allee', 'Kopenhagener Strasse', 'Pankower Allee', 'Pankstrasse', 'U-Bhf. Gesundbrunnen', 'RÃ¼gener Strasse', 'LÃ¼barser Strasse', 'Bhf. Wittenau', 'Alt-Wittenau', 'Tor 5', 'Bhf. Eichbornstrasse', 'Louise-Schroeder-Platz', 'Afrikanische Strasse', 'Virchow-Krankenhaus', 'Bhf. PutlitzStrasse', 'TurmStrasse', 'Wentowsteig', 'ZobeltitzStrasse', 'U-Bhf. Scharnweberstrasse, Sportplatz', 'Schillingstrasse', 'U-Bhf. Kurt-Schumacher-Platz', 'Humboldtstrasse', 'Sebastianfriedhof', 'Teichstrasse', 'Osloer Strasse', 'Exerzierstrasse', 'Bhf. Gesundbrunnen', 'Gartenplatz, Feldstrasse', 'Wittenau', 'Heilst tten, Wittenau', 'Auguste-Viktoria-Allee', 'Petersallee (Freilichtb hne Rehberge)', 'Sansibarstrasse', 'T rkenstrasse', 'Seestrasse', 'U-Bhf. Leopoldplatz', 'Triftstrasse', 'Nettelbeckplatz', 'Gerichstrasse', 'Lenzener Platz', 'Grenzstrasse', 'Gartenplatz', 'Bernauer Strasse Ecke Gartenstrasse', 'Bhf. Wollankstrasse', 'Badstrasse', 'Brunneplatz', 'Wiesenstrasse', 'Bhf. Wedding', 'Bhf. Wilhelmsruh', 'Sch fersee, Pankower Allee', 'Letteplatz, Strassenbahnhof', 'Provinzstrasse/Pankower Allee', 'Ritterlandweg', 'Prinzenallee/Soldiner Strasse', 'Badstrasse/Prinzenallee', 'Ramlerstrasse', 'Usedomer Strasse', 'Bernauer Strasse/Brunnenstrasse', 'Wolliner Strasse']
# Community 26: ['Rathaus Spandau', 'Pichelsdorfer Strasse', 'PÃ¤wesiner Weg', 'Heerstrasse', 'Weinmeisterhornweg', 'Wilhelmstrasse', 'BismarckStrasse', 'Oberhofer Platz', 'Saaleckplatz', 'Hafenplatz', 'Machandelweg', 'U-Bhf. Ruhleben', 'Friedhof Ruhleben', 'Kinderheim Ruhleben', 'Teltower Strasse', 'Grenadierstrasse', 'Stresowplatz', 'Breite Strasse', 'Brunsb tteler Damm', 'Nauener Strasse', 'Egelpfuhlstrasse', 'Magistratsweg', 'Spandauer Strasse', 'Hackbuschstrasse', 'Heidebergplan', 'Bhf. Steglitz', 'Spandau, Friedhof', 'Askanierring', 'Adamstrasse', 'Ortsgrenze Gatow', 'Gatow, Kirche', 'Gro glienicker Weg', 'Krankenhaus Hohengatow', 'Krankenhaus Havelh he', 'Alt-Kladow', 'Schwiezerhaus', 'Gutshof', 'Germersheimer Platz', 'Gatower Strasse', 'Krampnitzer Weg', 'Hottengrund', 'Hauptkinderheim', 'Bhf. Spandau-West', 'Hochgerichtstrasse', 'Falkenseer Chaussee', 'Viersener Strasse', 'Wolburgsweg', 'Stadtrandstrasse', 'Waldkrankenhaus', 'Radelandstrasse', 'Pionierstrasse', 'ZweiBrÃ¼cker Strasse', 'Bezirksamt', 'Moritzstrasse', 'Staakener Strasse', 'Dyotzer Strasse', 'Leuthingerweg', 'Strasse 393', 'Seegefelder Weg', 'Lynastrasse', 'Klinkeplatz', 'Hohenzollernring']
# Community 27: ['Waldfriedhof', 'Quantzstrasse', 'Kronprinzessinen Weg', 'Am Grossen Wannsee', 'Pfaueninsel-Chaussee', 'Rathaus Wannsee', 'St lpchensee', 'Kohlhasenbr ck', 'Schopenhauerstrasse', 'Bhf. Nikolassee', 'Am Beelitzhof', 'Bhf. Wannsee', 'StÃ¶lpchensee', 'KÃ¶nigstrasse/Kronprinzessinnenweg', 'KoblanckStrasse', 'Colomierstrasse', 'Krankenhaus Wannsee', 'Zum Heckeshorn', 'Krankenhaus Heckeshorn', 'KÃ¶nigstrasse', 'Endestrasse', 'Friedenstrasse', 'Sch ferberg', 'Nikolskoer Weg', 'Schloss Glienicke', 'Glienicker BrÃ¼cke']
# Community 36: ['Bhf. Yorckstrasse', 'Katzbachstrasse', 'Mehringdamm', 'Gottlieb-Dunkel-Strasse', 'GrÃ¼ner Weg', 'Gutschmidtstrasse', 'Loewenhardtdamm', 'Dudenstrasse', 'Kreuzbergstrasse', 'Yorckstrasse', 'Zossener Strasse', 'SÃ¼dstern', 'Urban-Krankenhause', 'U-Bhf. Prinzenstrasse', 'U-Bhf Kottbusser Tor', 'Oranienstrasse', 'Waldemarstrasse', 'Mariannenplatz', 'KÃ¶penicker Strasse', 'U-Bhf. Schlesisches Tor', 'Heckmannufer', 'Alt-Marienfelde', 'Gutshof Marienfelde', 'Bhf. Buckower Chaussee', 'Lichtenrader Damm', 'B hler Weg', 'Buckower Friedhof', 'Buckower Damm', 'Triftweg', 'Rudower Strasse', 'Efeuweg', 'Wildmeisterdamm', 'Friedhof Rudow', 'Kanalstrasse', 'Mimosenweg']
# Community 31: ['Hessenwinkel, Lindenstrasse', 'Fahlenbergstrasse Ecke FÃ¼rstenwalder Allee', 'S-Bhf. Wilhelmshagen', 'Zentralschule -WaldschÃ¤nke', 'S-Bhf. Rahnsdorf', 'Fichtenau, Stadtgrenze']
# Community 32: ['Altglienicke, Kirche', 'Gerosteig', 'Dankmarsteig']
# Community 35: ['S-Bhf. Kaulsdorf, Planitzstrasse', 'Chemnitzer Strasse', 'Ulmenstrasse', 'Gehsener Strasse', 'S-Bhf. KÃ¶penick', 'Bahnhofstrasse Ecke Lindenstrasse', 'KÃ¶penick, Krankenhaus', 'Chausseehaus', 'Alt-MÃ¼ggelheim']
# Community 37: ['Waltersdorf', 'Bohnsdorf, Waldstrasse', 'Eichbuschplatz', 'Joachimstrasse', 'S-Bhf. GrÃ¼nau', 'Diepensee, Flughafen', 'Waltersdorfer Chaussee (Spinne)', 'Sch nefeld, Siedlung', 'Bohnsdorf, Kirche', 'Gartenstadtweg', 'Gro Ziethen', 'Bhf. Gro Ziethen', 'Klein Ziethen', 'Wa mannsdorf, Warteh.', 'Selchow', 'Waltersforder Chaussee (Spinne)']
# Community 38: ['Wartenberg, Siedlung', 'Wartenberg, Dorfstrasse', 'Falkenberger Chaussee', 'Kolonie "Land in Sonne"""', 'Hohensch nhausen, Falkenberger Strasse']
# Community 39: ['Buch, Zepernicker Strasse', 'Alt-Buch', 'Lindenberger Weg', 'Karow, Bahnhofstrasse', 'G terau enring', 'Blankenburg, Bahnhofstrasse', 'Heinersdorf, Kirche', 'Am Steinberg', 'Ostseestrasse (Spitze)', 'Wilhelmsruh, Fontanestrasse', 'Hauptstrasse Ecke Edelwei strasse', 'Ehrenmal', 'Heinrich-Mann-Platz', 'Pankow, Rathaus', 'Pankow, Kirche', 'Prenzlauer Promenade Ecke Kissingenstrasse', 'Langhans Strasse Ecke Gustav-Adolf-Strasse', 'Hamburger Platz', 'Pistoriusstrasse Ecke Klement-Gottwald-Allee', 'Klement-Gottwald-Allee Ecke Bernkasteler Strasse', 'Wei ensee, Schwarzelfenweg', 'Ahrensfeld, Kirche', 'Stadtrandsiedlung', 'Falkenberg, Schule', 'Strasse nach Wartenberg', 'Malchower Weg', 'Falkenberger Strasse', 'Feldtmannstrasse', 'Malchow, Dorfstrasse', 'S-Bhf. Wollkanstrasse', 'Retzbacher Weg', 'Wei ensee, Rennbahnstrasse Ecke Gustav-Adolf-Strasse', 'Gro e Seestrasse Ecke Klement-Gottwald-Allee', 'Wei ensee, Liebermannstrasse Ecke Piesporter Strasse', 'Wei ensee, Feldtmannstrasse', 'Rennbahnstrasse Ecke Gustav-Adolf-Strasse', 'Prenzlauer Allee (Spitze)', 'Wicherstrasse', 'Glienicke, Kirche', 'Els sser Strasse', 'Schildow, Kirche', 'Blankenfelde, Hauptstrasse', 'Kolonie "Daheim"""', 'Nordend', 'Ossietzkyplatz', 'Kurt-Fischer-Platz', 'U-Bhf. Vinetastrasse', 'Neu-Lindenberg', 'Lindenberg', 'S-Bhf. Hohen Neuendorf', 'Bergfelde, Karl-Marx-Strasse', 'Sch nflie , Kirche', 'Glienicke, Breitscheidstrasse']
# Community 4: ['B rknersfelde', 'Marzahn, Berliner Chaussee', 'G terbahnhof Springpfuhl', 'S-Bhf. Friedrichsfelde-Ost', 'Schlossstrasse Ecke Alt-Friedrichsfelde', 'U-Bhf. Friedrichsfelde', 'Kniprodestrasse Ecke Erml ndische Strasse', 'KÃ¶nigstor', 'S-Bhf. Alexanderplatz', 'Marx-Engels-Platz', 'Bhf. Friedrichstrasse', 'Albrechtstrasse', 'Robert-Koch-Platz', 'Waldesruh', 'Malhlsdorfer Allee', 'Fichtestrasse Ecke Schopenhauerstrasse', 'Hultschiner Damme', 'Sadowastrasse', 'Chemnitzer Ecke Ulmenstrasse', 'Eichenallee', 'Alt-Biesdorf, Oberfeldstrasse', 'Kurische Strasse', 'Chausseestrasse Ecke Invalidenstrasse', 'Scharnhorst- Ecke Kieler Strasse', 'Kosterstrasse', 'Andreasstrasse', 'K striner Platz', 'Warschauer Strasse', 'Holteistrasse', 'S-Bhf. Rummelsburg', 'M nsterlandstrasse', 'Bhf. Lichtenberg', 'BVG-Bf. Lichtenberg, Siegfriestrasse', 'Roederplatz', 'Proskauer Ecke Dolziger Strasse', 'Ebertystrasse Ecke Leninallee', 'Greifswalderstrasse Ecke Dimitroffstrasse', 'Klosterstrasse', 'Alt-Marzahn, Kirche', 'Elisabethstrasse', 'Ecilienstrasse', 'S-Bhf. Biesdorf', 'Ostbahnhof', 'Stalinallee', 'Leninplatz', 'Rosenthaler Platz', 'Oranienburger Tor', 'Dingelst dter Strasse', 'Siegfriestrasse', 'Wei enseer Weg', 'Oderbruchstrasse', 'Dimitroffstrasse']
# Community 41: ['H now, Dorfstrasse', 'Greifswalder Strasse', 'Am Rosenhag', 'S-Bhf. Mahlsdorf']
# Community 43: ['Bhf. SchÃ¶neweide', 'Sterndamm', 'Johannisthaler Chaussee', 'Baumschulenstrasse Ecke SÃ¼dostallee', 'S-Bhf. Baumschulenweg', 'Eichbuschallee', 'Treptow, Rathaus', 'S-Bhf. Treptower Park']
# Community 0: ['Kaulsdorf, Bausdorfstrasse', 'Ridbacher Strasse', 'Grottkauer Strasse', 'Uckermarkstrasse']
# Community 33: ['Jerusalems-Kirche, Lindenstrasse', 'Moritzplatz', 'Oranienplatz', 'U-Bhf. Kottbusser Tor', 'Kottbusser BrÃ¼cke', 'Hohenstaufenplatz', 'Hermannplatz', 'Reuterstrasse', 'Fuldastrasse', 'Erkstrasse', 'Hertzbergplatz', 'Bhf. Sonnenallee', 'Dammweg', 'NeukÃ¶llnische Allee', 'Am Oberhafen', 'U-Bhf. Grenzallee']
# Community 34: ['Kinderheim', 'Friedrich-Junge-Strasse', 'Markgrafendamm']
# Community 7: ['Alt-Schm ckwitz', 'Eichwalde, Uhlandstrasse', 'Bhf. Eichwalde', 'Konsum Wernsdorf', 'Konsum Ziegenhals', 'Ziegenhals, VA Dienststelle']
# Community 8: ['Kladow', 'Wannsee']
# Community 40: ['VinetastraÃŸe metro station', 'SchÃ¶nhauser Allee (metro station)', 'Eberswalder StraÃŸe metro station', 'U-Bahnhof Senefelderplatz', 'Rosa-Luxemburg-Platz station', 'Alexanderplatz u-bahn station', 'KlosterstraÃŸe station', 'MÃ¤rkisches Museum station', 'Spittelmarkt station', 'Hausvogteiplatz station', 'Stadtmitte station', 'MohrenstraÃŸe metro station', 'Potsdamer Platz metro station', 'U-Bahnhof Gesundbrunnen', 'VoltastraÃŸe', 'Bernauer StraÃŸe station', 'Rosenthaler Platz station', 'WeinmeisterstraÃŸe metro station', 'ScharnweberstraÃŸe', 'Strausberger Platz', 'Weberwiese', 'Frankfurter Tor metro station', 'SamariterstraÃŸe metro station', 'Berlin Frankfurter Allee station', 'MagdalenenstraÃŸe', 'Lichtenberg metro station', 'Friedrichsfelde']
# Community 42: ['Gleisdreieck', 'BÃ¼lowstraÃŸe metro station', 'Nollendorfplatz metro station', 'Wittenbergplatz metro station', 'Zoologischer Garten metro station', 'Ernst-Reuter-Platz metro station', 'Deutsche Oper', 'Sophie-Charlotte-Platz', 'Kaiserdamm', 'Theodor-Heuss-Platz', 'SpichernstraÃŸe metro station', 'Hohenzollernplatz', 'U-Fehrbelliner Platz', 'Heidelberger Platz', 'RÃ¼desheimer Platz', 'Breitenbachplatz metro station', 'Podbielskiallee', 'Dahlem-Dorf', 'Freie UniversitÃ¤t (Thielplatz) metro station', 'Oskar-Helene-Heim metro station', 'Onkel Toms HÃ¼tte metro station', 'Krumme Lanke metro station', 'Richard-Wagner-Platz metro station', 'KurfÃ¼rstenstraÃŸe metro station', 'Neu-Westend', 'Olympia-Stadion station', 'Ruhleben station', 'Viktoria-Luise-Platz', 'Bayerischer Platz station', 'Rathaus SchÃ¶neberg', 'Innsbrucker Platz metro station']
# Community 12: ['Warschauer StraÃŸe metro station', 'Schlesisches Tor', 'GÃ¶rlitzer Bahnhof', 'Kottbusser Tor station', 'PrinzenstraÃŸe', 'Hallesches Tor', 'MÃ¶ckernbrÃ¼cke U-Bahn station', 'Alt-Tegel metro station', 'Borsigwerke', 'Holzhauser StraÃŸe', 'OtisstraÃŸe', 'ScharnweberstraÃŸe', 'Kurt-Schumacher-Platz', 'Afrikanische StraÃŸe', 'Rehberge', 'SeestraÃŸe', 'Leopoldplatz metro station', 'U-Bahnhof Wedding', 'Reinickendorfer StraÃŸe', 'SchwartzkopffstraÃŸe', 'Naturkundemuseum metro station', 'Oranienburger Tor metro station', 'FriedrichstraÃŸe metro station', 'FranzÃ¶sische StraÃŸe metro station', 'Stadtmitte station', 'KochstraÃŸe', 'Mehringdamm', 'GneisenaustraÃŸe', 'SÃ¼dstern', 'Hermannplatz', 'Rathaus NeukÃ¶lln', 'Karl-Marx-StraÃŸe', 'NeukÃ¶lln (SÃ¼dring) metro station', 'Grenzallee', 'OtisstraÃŸe', 'ParadestraÃŸe metro station', 'Tempelhof (SÃ¼dring) metro station', 'JannowitzbrÃ¼cke metro station', 'Heinrich-Heine-StraÃŸe station', 'Moritzplatz station', 'SchÃ¶nleinstraÃŸe metro station', 'BoddinstraÃŸe', 'LeinestraÃŸe']
# Community 17: ['S-Bahnhof Berlin-Gesundbrunnen', 'S-Bahnhof SchÃ¶nhauser Allee', 'Berlin Prenzlauer Allee station', 'Berlin Greifswalder StraÃŸe station', 'Berlin Landsberger Allee station', 'Berlin Storkower StraÃŸe station', 'S-Bahnhof Frankfurter Allee', 'S-Bahnhof Ostkreuz', 'Berlin Messe Nord/ICC station', 'Berlin-Westend station', 'S-Bahnhof Jungfernheide', 'Berlin BeusselstraÃŸe station', 'Berlin Westhafen station', 'Berlin-Wedding station', 'Berlin-Blankenburg station', 'Berlin-Pankow-Heinersdorf station', 'S-Bahnhof Pankow', 'S-Bahnhof Warschauer StraÃŸe', 'Gartenfeld', 'Berlin-Siemensstadt railway station', 'Berlin Wernerwerk station', 'S-Bahnhof FriedrichstraÃŸe', 'Berlin Hackescher Markt station', 'S-Bahnhof Berlin Alexanderplatz', 'S-JannowitzbrÃ¼cke station', 'S-Bahnhof Berlin Ostbahnhof', 'Berlin-Rummelsburg railway station', 'Betriebsbahnhof Rummelsburg station', 'S-Bahnhof Berlin Karlshorst', 'Berlin Wuhlheide station', 'Berlin-KÃ¶penick station', 'Berlin Hirschgarten station', 'Berlin-Friedrichshagen station', 'Berlin-Rahnsdorf station', 'Berlin Wilhelmshagen station', 'Erkner railway station', 'Oranienburg station', 'Lehnitz station', 'Borgsdorf station', 'Birkenwerder station', 'Hohen Neuendorf station', 'Berlin-Frohnau station', 'Berlin-Hermsdorf station', 'Berlin-Waidmannslust station', 'S-Bahnhof Berlin-Wittenau', 'Berlin-Wilhelmsruh station', 'Berlin-SchÃ¶nholz station', 'Berlin WollankstraÃŸe station', 'Berlin Bornholmer StraÃŸe station', 'Berlin Humboldthain station', 'Berlin Nordbahnhof', 'Berlin Oranienburger StraÃŸe station', 'Berlin Brandenburger Tor station', 'Potsdamer Platz S-Bahn station', 'S-Bahnhof Berlin Anhalter Bahnhof', 'Bernau bei Berlin station', 'Zepernick station', 'RÃ¶ntgental station', 'Berlin-Buch station', 'S-Bahnhof Berlin Karow']
# Community 22: ['Berlin Treptower Park station', 'Berlin Sonnenallee station', 'S-Bahnhof Berlin NeukÃ¶lln', 'S-Bahnhof HermannstraÃŸe', 'S-Bahnhof Berlin-Tempelhof', 'S-Bahnhof Berlin SÃ¼dkreuz', 'Berlin-SchÃ¶neberg station', 'S-Bahnhof Innsbrucker Platz', 'Berlin Bundesplatz station', 'Berlin Heidelberger Platz station', 'Berlin Hohenzollerndamm station', 'KÃ¶llnische Heide station', 'Berlin-Baumschulenweg station', 'S-Bahnhof Berlin SchÃ¶neweide', 'Berlin-Johannisthal railway station', 'Berlin-Adlershof station', 'S-Bahnhof GrÃ¼nau', 'PlÃ¤nterwald railway station', 'Eichwalde station', 'Zeuthen railway station', 'Wildau railway station', 'KÃ¶nigs Wusterhausen station', 'Oberspree station', 'Berlin-Spindlersfeld station', 'YorckstraÃŸe (GroÃŸgÃ¶rschenstraÃŸe) station', 'YorckstraÃŸe station', 'Priesterweg railway station', 'AttilastraÃŸe station', 'Marienfelde station', 'Buckower Chaussee station', 'Lichtenrade station', 'Mahlow station', 'S-Bahnhof Blankenfelde', 'Dahlewitz railway station', 'Rangsdorf railway station', 'SÃ¼dende station', 'Lankwitz station', 'S-Bahnhof Berlin Lichterfelde-Ost', 'Lichterfelde SÃ¼d station', 'Teltow railway station']
# Community 23: ['Berlin-Halensee station', 'Berlin Westkreuz station', 'Berlin-Staaken station', 'S-Bahnhof Berlin Spandau', 'S-Bahnhof Berlin Spandau', 'Berlin-Pichelsberg railway station', 'Berlin Olympiastadion station', 'Berlin HeerstraÃŸe station', 'Berlin Messe SÃ¼d railway station', 'S-Bahnhof Berlin Charlottenburg', 'Berlin Savignyplatz station', 'S-Bahnhof Berlin Zoologischer Garten', 'Berlin-Tiergarten station', 'Berlin Bellevue station', 'Berlin Lehrter Stadtbahnhof', 'Potsdam Hauptbahnhof', 'Potsdam-Babelsberg station', 'Potsdam Griebnitzsee railway station', 'S-Bahnhof Berlin Wannsee', 'Berlin-Nikolassee station', 'Berlin-Grunewald station', 'Falkensee railway station', 'Berlin Albrechtshof station', 'Siemensstadt-FÃ¼rstenbrunn station', 'Berlin-Friedenau station', 'Berlin FeuerbachstraÃŸe station', 'S-Bahnhof Rathaus Steglitz', 'Berlin Botanischer Garten station', 'S-Bahnhof Berlin Lichterfelde West', 'Berlin Sundgauer StraÃŸe station', 'Berlin-Zehlendorf station', 'Berlin Mexikoplatz station', 'Berlin-Schlachtensee station', 'Berlin-DÃ¼ppel railway station', 'Dreilinden station', 'Stahnsdorf railway station']
# Community 28: ['NÃ¶ldnerplatz station', 'Berlin-Lichtenberg station', 'Berlin-Friedrichsfelde Ost station', 'Berlin-Biesdorf station', 'Berlin-Kaulsdorf railway station', 'Mahlsdorf railway station', 'Hoppegarten (Mark) station', 'Neuenhagen station', 'Fredersdorf station', 'Petershagen Nord railway station', 'Strausberg station', 'Strausberg Stadt station', 'Strausberg Nord station']
# Community 30: ['Velten (Mark)', 'Bahnhof HohenschÃ¶pping', 'Hennigsdorf station', 'Hennigsdorf station', 'Stolpe SÃ¼d station', 'Heiligensee station', 'Schulzendorf railway station', 'Berlin-Tegel railway station', 'Eichborndamm station', 'S-Bahnhof Berlin-Wittenau', 'Berlin Alt-Reinickendorf station']

# %%
import community as community_louvain

# %%
# Calculate Degree Centrality
degree_centrality = nx.degree_centrality(G)

# Calculate Betweenness Centrality
betweenness_centrality = nx.betweenness_centrality(G)

# Calculate Closeness Centrality
closeness_centrality = nx.closeness_centrality(G)

# %%
# Print the top 5 nodes with the highest degree centrality and their node labels
print("Top 5 Degree Centrality Nodes:")
sorted_degree_centrality = sorted(degree_centrality.items(), key=lambda x: x[1], reverse=True)
for node, centrality in sorted_degree_centrality[:5]:
    node_label = G.nodes[node]["node_label"]
    print(f"Node {node_label}: {centrality}")

# Degree Centrality (C_deg(v)) = (Number of edges connected to node v) / (Total number of nodes in the network - 1)

# Example questions:
# 1. Which stations have the highest number of direct connections (degree centrality)?
# 2. What are the major transfer hubs where passengers can switch between different modes of transport?
    #for this I first need to create "supernodes" based on location that can be analysed
# Out:
# Top 5 Degree Centrality Nodes:
# Node Wittenbergplatz: 0.011816838995568686
# Node Dimitroffstrasse: 0.011816838995568686
# Node S-Bahnhof Ostkreuz: 0.011816838995568686
# Node U Eberswalder StraÃŸe: 0.010339734121122601
# Node Bhf. Zoo: 0.010339734121122601

# %%
# Print the top 5 nodes with the highest betweenness centrality
print("\nTop 5 Betweenness Centrality Nodes:")
sorted_betweenness_centrality = sorted(betweenness_centrality.items(), key=lambda x: x[1], reverse=True)
for node, centrality in sorted_betweenness_centrality[:5]:
    node_label = G.nodes[node]["node_label"]
    print(f"Node {node_label}: {centrality}")

# based on the concept of "shortest paths." Nodes with high betweenness centrality act as bridges or intermediaries that connect different parts of the network, and they are crucial for maintaining network connectivity
# fraction of all shortest paths in the network that pass through node

# Example questions:
# 1. Which stations act as critical points for passenger flow, serving as bridges between different parts of the network?
# 2. Where are the potential bottlenecks in the network that might experience high congestion?
# Out:
# Top 5 Betweenness Centrality Nodes:
# Node Potsdamer Strasse: 0.05205940663342261
# Node Bhf. SchÃ¶neweide: 0.041706446759938835
# Node Hermannplatz: 0.0408390481001322
# Node Elsenstrasse: 0.038964486682892104
# Node Am Treptower Park Ecke Bulgarische Strasse: 0.03868162055357283

# %%
# Print the top 5 nodes with the highest closeness centrality
print("\nTop 5 Closeness Centrality Nodes:")
sorted_closeness_centrality = sorted(closeness_centrality.items(), key=lambda x: x[1], reverse=True)
for node, centrality in sorted_closeness_centrality[:5]:
    node_label = G.nodes[node]["node_label"]
    print(f"Node {node_label}: {centrality}")#

#closeness centrality measures how efficiently a node can reach other nodes in the network

# Example questions:
# 1. Which stations are most accessible to the rest of the network, providing shorter travel times for passengers?
# 2. What locations are suitable for setting up key amenities or services to serve a large number of passengers?
# Out:
# Top 5 Closeness Centrality Nodes:
# Node Potsdamer Strasse: 0.05477712282058007
# Node Berliner Strasse: 0.05362919610267535
# Node Hafenplatz: 0.05233171555180417
# Node LÃ¼tzowplatz: 0.050909418995759056
# Node Rathaus Spandau: 0.050823976614227724
